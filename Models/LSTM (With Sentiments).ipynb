# %%
import io
from google.colab import drive
drive.mount("gdrive")

#Import the libraries
import math
import pandas_datareader as web
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
plt.style.use('fivethirtyeight')

data = pd.read_csv(r'/content/gdrive/My Drive/Colab Notebooks/ML/latest_data.csv')
data.head
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at gdrive
# <bound method NDFrame.head of             Date         Open         High  ...     bb_bbw  polarity  Tpolarity
# 0     2015-03-19  4424.790039  4440.009766  ...   0.195261  0.088056   0.194262
# 1     2015-03-20  4468.290039  4478.680176  ...   1.448917  0.139082   0.229021
# 2     2015-03-23  4454.149902  4466.339844  ...   1.308734  0.106942   0.116388
# 3     2015-03-24  4444.390137  4467.790039  ...   1.200656  0.160641   0.302989
# 4     2015-03-25  4437.379883  4442.540039  ...   3.792607  0.008614   0.199642
# ...          ...          ...          ...  ...        ...       ...        ...
# 1236  2020-02-14  9613.879883  9634.750000  ...   8.891287  0.136662   0.028824
# 1237  2020-02-18  9567.280273  9647.719727  ...   9.356037  0.035635   0.192635
# 1238  2020-02-19  9683.940430  9736.570313  ...   9.964035  0.105493  -0.057850
# 1239  2020-02-20  9696.660156  9714.230469  ...  10.186817  0.062461   0.138628
# 1240  2020-02-21  9582.540039  9594.000000  ...  10.109588  0.034040   0.062477
#
# [1241 rows x 21 columns]>

# %%
train_data = (data['Low']+data['High'])/2.0
plt.figure(figsize = (18,9))
plt.plot(range(data.shape[0]),train_data)
plt.xticks(range(0,data.shape[0],60),data['Date'].loc[::60],rotation=45)
plt.xlabel('Date',fontsize=20)
plt.ylabel('Mid Price',fontsize=18)
plt.show()

# %%
dataset = train_data.values
# training_data_len = math.ceil( len(dataset) *.8)

# %%
#Scale the all of the data to be values between 0 and 1 
scaler = MinMaxScaler(feature_range=(0, 1)) 
# dataset = dataset.reshape(-1, 1)
# scaled_data = scaler.fit_transform(dataset)

# %%
data["Midvalues"] = train_data

# data['features'] = data[['Midvalues','polarity', 'Tpolarity']].values.tolist()
# midvalues = train_df.Midvalues.values.reshape(-1, 1)
# polarity = train_df.polarity.values.reshape(-1, 1)
# Tpolarity = train_df.Tpolarity.values.reshape(-1, 1)
# train = list(zip(midvalues, polarity,Tpolarity))
# train_reshaped = np.array(train).reshape(993, 3)
# scaled_train = scaler.fit_transform(train_reshaped)
# scaled_train

# %%
from sklearn.model_selection import KFold # import KFold
from tensorflow.python.keras.datasets import mnist
from tensorflow.python.keras.layers.core import Dense, Dropout, Activation, Flatten
from tensorflow.python.keras.layers import LSTM
from tensorflow.python.keras.models import Sequential
from tensorflow.python.keras.utils import np_utils


# 1182 data
kf = KFold(n_splits=5, shuffle=False) # Define the split - into 5 folds 
predictions_list = []
for train, test in kf.split(data):
  # train
  train_df = data.iloc[train]
  midvalues = train_df.Midvalues.values.reshape(-1, 1)
  polarity = train_df.polarity.values.reshape(-1, 1)
  Tpolarity = train_df.Tpolarity.values.reshape(-1, 1)
  train = list(zip(midvalues, polarity,Tpolarity))
  train_reshaped = np.array(train).reshape(len(train),3)
  scaled_train = scaler.fit_transform(train_reshaped)

  # print(scaled_train.shape)
  # print(scaled_train)

  # test
  test_df = data.iloc[test]
  midvalues = test_df.Midvalues.values.reshape(-1, 1)
  polarity = test_df.polarity.values.reshape(-1, 1)
  Tpolarity = test_df.Tpolarity.values.reshape(-1, 1)
  combined = list(zip(midvalues, polarity,Tpolarity))
  test_reshaped = np.array(combined).reshape(len(combined),3)
  scaled_test = scaler.transform(test_reshaped)

  # print(scaled_test.shape)
  # print(scaled_test)

  #Split the data into x_train and y_train data sets
  X_train=[]
  Y_train = []
  for i in range(60,len(scaled_train)):
      X_train.append(scaled_train[i-60:i])
      Y_train.append(scaled_train[i])

  X_test=[]
  Y_test = []
  y_test_index = []
  for i in range(60,len(scaled_test)):
      X_test.append(scaled_test[i-60:i])
      Y_test.append(scaled_test[i])
      y_test_index.append(test[i])

  # print(y_test_index)

  X_train, Y_train, X_test, Y_test= np.array(X_train), np.array(Y_train), np.array(X_test), np.array(Y_test)
  X_train = np.reshape(X_train, (X_train.shape[0],X_train.shape[1],3))
  X_test = np.reshape(X_test, (X_test.shape[0],X_test.shape[1],3))

  # print(X_train.shape)
  # print(Y_train.shape)
  # print(X_test.shape)
  # print(Y_test.shape)

  # Creating the model
  model = Sequential()
  model.add(LSTM(units=200, return_sequences=True,input_shape=(X_train.shape[1],3)))
  model.add(LSTM(units=200, return_sequences=False))
  model.add(Dense(units=25))
  model.add(Dense(units=3))
  model.compile(optimizer='adam', loss='mean_squared_error')

  #Train the model
  model.fit(X_train, Y_train, batch_size=10, epochs=50)

  predictions = model.predict(X_test)
  trainPredict_dataset_like = np.zeros(shape=(len(predictions), 3))
  # put the predicted values in the right field
  trainPredict_dataset_like[:,0] = predictions[:,0]
  trainPredict_dataset_like[:,1] = predictions[:,1]
  trainPredict_dataset_like[:,2] = predictions[:,2]

  # inverse transform and then select the right field
  predictions = scaler.inverse_transform(trainPredict_dataset_like)

  rmse=np.sqrt(np.mean(((predictions - Y_test)**2)))
  print(rmse)

  #Plot/Create the data for the graph
  # print(len(predictions))
  predictions = [item[0] for item in predictions] 
  predictions = pd.Series(predictions, index = y_test_index, name="Predictions")  
  # display(predictions)
  test_df = pd.concat([test_df, predictions], axis=1, sort=False)
  # display(test_df)
  # test_df['Predictions'] = predictions

  predictions_list.extend([0]*60 + list(predictions))

  #Visualize the data
  plt.figure(figsize=(16,8))
  plt.title('Model')
  plt.xlabel('Date', fontsize=18)
  plt.ylabel('Mid Price USD ($)', fontsize=18)
  plt.plot((data['Low']+data['High'])/2.0)
  plt.plot((test_df['Low']+test_df['High'])/2.0)
  plt.plot(test_df['Predictions'])
  plt.legend(['Train', 'Actual', 'Predictions'], loc='lower right')
  plt.xticks(range(0,data.shape[0],60),data['Date'].loc[::60],rotation=45)
  plt.show()
# Out:
# Epoch 1/50
# 94/94 [==============================] - 47s 502ms/step - loss: 0.0199
# Epoch 2/50
# 94/94 [==============================] - 47s 501ms/step - loss: 0.0119
# Epoch 3/50
# 94/94 [==============================] - 47s 500ms/step - loss: 0.0111
# Epoch 4/50
# 94/94 [==============================] - 47s 501ms/step - loss: 0.0114
# Epoch 5/50
# 94/94 [==============================] - 47s 499ms/step - loss: 0.0115
# Epoch 6/50
# 94/94 [==============================] - 47s 499ms/step - loss: 0.0108
# Epoch 30/50
# 94/94 [==============================] - 48s 511ms/step - loss: 0.0098
# Epoch 31/50
# 94/94 [==============================] - 48s 510ms/step - loss: 0.0099
# Epoch 32/50
# 94/94 [==============================] - 48s 510ms/step - loss: 0.0098
# Epoch 33/50
# 94/94 [==============================] - 48s 507ms/step - loss: 0.0097
# Epoch 34/50
# 94/94 [==============================] - 48s 511ms/step - loss: 0.0098
# Epoch 35/50
# 94/94 [==============================] - 48s 508ms/step - loss: 0.0098
# Epoch 36/50
# 94/94 [==============================] - 48s 508ms/step - loss: 0.0095
# Epoch 37/50
# 94/94 [==============================] - 48s 515ms/step - loss: 0.0096
# Epoch 38/50
# 94/94 [==============================] - 48s 511ms/step - loss: 0.0095
# Epoch 39/50
# 94/94 [==============================] - 48s 510ms/step - loss: 0.0096
# Epoch 40/50
# 94/94 [==============================] - 48s 508ms/step - loss: 0.0096
# Epoch 41/50
# 94/94 [==============================] - 48s 509ms/step - loss: 0.0095
# Epoch 42/50
# 94/94 [==============================] - 48s 512ms/step - loss: 0.0094
# Epoch 43/50
# 94/94 [==============================] - 48s 514ms/step - loss: 0.0095
# Epoch 44/50
# 94/94 [==============================] - 48s 514ms/step - loss: 0.0095
# Epoch 45/50
# 94/94 [==============================] - 48s 511ms/step - loss: 0.0095
# Epoch 46/50
# 94/94 [==============================] - 48s 512ms/step - loss: 0.0096
# Epoch 47/50
# 94/94 [==============================] - 48s 510ms/step - loss: 0.0095
# Epoch 48/50
# 94/94 [==============================] - 48s 511ms/step - loss: 0.0094
# Epoch 49/50
# 94/94 [==============================] - 48s 511ms/step - loss: 0.0095
# Epoch 50/50
# 94/94 [==============================] - 48s 513ms/step - loss: 0.0094
# 4674.286663470225

# %%
last_sect = data

last_sect['Predictions'] = predictions_list
last_sect = last_sect[last_sect['Predictions'] != 0]
def output_direction(df):
  if df['Predictions'] > df['Adj Close']:
    return 0
  else:
    return 1

last_sect['Direction_predicted'] = last_sect.apply(output_direction, axis = 1)
count = 0
for index, row in last_sect.iterrows():
  if row['Direction_predicted'] == row['Direction']:
    count += 1

print(count/len(last_sect))
# Out:
# 0.5961742826780021
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()

# %%
  #Visualize the data
  plt.figure(figsize=(16,8))
  plt.title('Model')
  plt.xlabel('Date', fontsize=18)
  plt.ylabel('Mid Price USD ($)', fontsize=18)
  # plt.plot((data['Low']+data['High'])/2.0)
  plt.plot((test_df['Low']+test_df['High'])/2.0)
  plt.plot(test_df['Predictions'])
  plt.legend([ 'Actual', 'Predictions'], loc='lower right')
  plt.xticks(range(1000,data.shape[0],60),data['Date'].loc[::60],rotation=45)
  plt.show()

# %%
last_sect = last_sect.reset_index()
profits = 0
for index, row in last_sect.iterrows():
  if row['Direction_predicted'] == 1 and index+6 < len(last_sect):
    profits += last_sect.loc[index+6, 'Adj Close'] - row['Adj Close']
  elif row['Direction_predicted'] == 0 and index+6 < len(last_sect):
     profits += row['Adj Close'] - last_sect.loc[index+6, 'Adj Close'] 

# 7 days price - today price (if want buy - 1)
profits
# Out:
# 20984.596205999977
